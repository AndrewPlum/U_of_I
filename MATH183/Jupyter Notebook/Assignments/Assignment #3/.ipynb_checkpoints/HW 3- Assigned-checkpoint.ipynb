# %% [markdown]
# ## Part 1: data modeling with Pandas
#
# __Problem 1:__ The cafeteria at UI has a data file to store the following information of its customer: (1) phone number, (2) list of items they have purchased, (3) unit price, (4) quantity (5) date of purchase (6) and time of each purchase. See attached image "cafe.png". Generate such a file as a DataFrame in Pandas with $20$ rows (make it as diverse as possible).

# %%
# import packages

import pandas as pd
import random
from random import randint
from random import choices
from datetime import date, timedelta, time

# make cafeteria DataFrame

cafeteria_df = pd.DataFrame(columns = ["Phone Number", "List of Items Purchased", "Unit Price", "Quantity", "Date of Purchase", "Time of Each Purchase"])

# declare variables

list_of_purchaseable_items = ["Pizza Slice", "Hamburger", "Chicken Tenders", "Salad", "Taco", "Burrito"]
start_date = date(2020, 1, 1)
end_date = date(2023, 12, 31)

# fill cafeteria Dataframe

for i in range(20):
    phone_number = "(" + str(randint(100,999)) + ")-" + str(randint(100,999)) + "-" + str(randint(1000,9999))
    list_of_items_purchased = "".join(choices(list_of_purchaseable_items, k=1))
    unit_price = randint(5,10)
    quantity = randint(1,5)
    random_date = start_date + timedelta(days=random.randint(0, (end_date - start_date).days))
    date_of_purchase = random_date.strftime('%b %d, %Y')
    random_time = time(random.randint(0, 23), random.randint(0, 59))
    time_of_each_purchase = random_time.strftime('%I:%M %p')
    cafeteria_df.loc[i] = [phone_number, list_of_items_purchased, unit_price, quantity, date_of_purchase, time_of_each_purchase]

# print cafeteria DataFrame
    
cafeteria_df
# Out:
#       Phone Number List of Items Purchased  Unit Price  Quantity  \
# 0   (423)-365-3577                   Salad          10         1
# 1   (739)-663-5967               Hamburger           8         5
# 2   (174)-521-4921                    Taco           7         3
# 3   (320)-533-1447                 Burrito          10         3
# 4   (614)-981-5595               Hamburger          10         1
# 5   (682)-654-7361               Hamburger           7         1
# 6   (129)-938-3283                    Taco           5         3
# 7   (264)-687-3547                   Salad           7         5
# 8   (455)-902-6816                   Salad           7         5
# 9   (791)-357-8190                    Taco           7         5
# 10  (460)-411-1467                   Salad           5         3
# 11  (586)-648-6141               Hamburger           5         3
# 12  (253)-218-9518                 Burrito           7         2
# 13  (277)-450-7776         Chicken Tenders           5         4
# 14  (478)-764-3818               Hamburger           7         4
# 15  (478)-238-8738                   Salad           9         4
# 16  (219)-390-2393               Hamburger           9         4
# 17  (455)-536-4464                 Burrito           6         5
# 18  (982)-609-5718                    Taco           9         2
# 19  (510)-297-8485                   Salad          10         1
#
#    Date of Purchase Time of Each Purchase
# 0      May 16, 2022              05:32 PM
# 1      Sep 03, 2023              07:44 AM
# 2      Jun 24, 2023              11:11 AM
# 3      Apr 15, 2023              12:32 PM
# 4      Sep 29, 2021              08:04 PM
# 5      Jan 06, 2023              08:53 AM
# 6      Dec 06, 2023              01:46 PM
# 7      Apr 08, 2022              11:53 PM
# 8      Feb 11, 2023              12:00 AM
# 9      Nov 12, 2022              08:59 AM
# 10     Jun 04, 2021              07:50 PM
# 11     Sep 23, 2021              05:03 AM
# 12     Aug 14, 2020              11:21 AM
# 13     May 26, 2023              03:30 AM
# 14     Dec 07, 2022              07:03 PM
# 15     Jun 12, 2022              10:11 PM
# 16     Mar 20, 2020              11:16 PM
# 17     Aug 01, 2020              04:36 AM
# 18     Dec 26, 2021              11:20 PM
# 19     May 04, 2022              05:50 PM

# %% [markdown]
# __Problem 2:__ The REC center at UI has a data file to store the following information of its members: (1) phone number, (2) date of visit (3) starting time of visit, (4) ending time of visit. Make such as data file as Pandas' DataFrame with $20$ rows.

# %%
# import packages

import pandas as pd
import random
from random import randint
from random import choices
from datetime import date, timedelta, time

# make REC center DataFrame

rec_center_df = pd.DataFrame(columns = ["Phone Number", "Date of Visit", "Starting Time of Visit", "Ending Time of Visit"])

# declare variables

start_date = date(2010, 1, 1)
end_date = date(2023, 12, 31)

# fill REC center Dataframe

for i in range(20):
    phone_number = "(" + str(randint(100,999)) + ")-" + str(randint(100,999)) + "-" + str(randint(1000,9999))
    random_date = start_date + timedelta(days=random.randint(0, (end_date - start_date).days))
    date_of_visit = random_date.strftime('%b %d, %Y')
    random_time = time(random.randint(0, 23), random.randint(0, 59))
    starting_time_of_visit = random_time.strftime('%I:%M %p')
    random_time = time(random.randint(0, 23), random.randint(0, 59))
    ending_time_of_visit = random_time.strftime('%I:%M %p')
    rec_center_df.loc[i] = [phone_number, date_of_visit, starting_time_of_visit, ending_time_of_visit]

# print REC center DataFrame
    
rec_center_df
# Out:
#       Phone Number Date of Visit Starting Time of Visit Ending Time of Visit
# 0   (955)-819-9922  Nov 19, 2015               07:50 AM             06:32 PM
# 1   (887)-572-9653  Nov 29, 2018               01:48 AM             01:49 AM
# 2   (105)-987-3843  Jun 04, 2020               07:09 AM             11:47 PM
# 3   (476)-202-4752  Jan 30, 2014               08:51 PM             10:44 AM
# 4   (884)-508-4845  Mar 25, 2014               11:45 AM             08:29 PM
# 5   (223)-205-8929  Mar 08, 2019               06:47 AM             08:50 PM
# 6   (436)-572-4110  Mar 01, 2018               07:45 PM             07:13 AM
# 7   (662)-840-7886  May 17, 2017               05:06 PM             09:33 PM
# 8   (819)-424-6154  May 14, 2016               06:32 AM             06:05 AM
# 9   (986)-741-1202  Apr 03, 2016               11:12 PM             07:12 AM
# 10  (716)-927-3683  Jan 16, 2013               05:40 PM             03:53 AM
# 11  (696)-583-9066  Mar 07, 2021               05:08 PM             05:16 AM
# 12  (885)-696-1758  Nov 24, 2019               09:36 AM             09:40 PM
# 13  (754)-217-2349  Oct 10, 2018               02:18 AM             09:46 AM
# 14  (989)-726-8760  Mar 15, 2014               09:45 AM             07:29 AM
# 15  (881)-718-2930  Dec 04, 2013               07:38 AM             01:43 PM
# 16  (740)-823-7811  Jul 13, 2019               04:47 PM             12:22 AM
# 17  (413)-974-4496  Jun 01, 2018               01:04 AM             03:45 PM
# 18  (734)-631-1000  Sep 25, 2011               11:04 PM             06:45 PM
# 19  (725)-947-5830  Jun 14, 2011               06:04 PM             03:19 AM

# %% [markdown]
# __Problem 3:__ The university wants to make a data file that contains the activities of both its Cafeteria and REC center. Write the code to generate such data file as a Pandas' DataFrame.

# %%
# merge DataFrames

#combined_ui_df = cafeteria_df.merge(rec_center_df,how='left', left_on='Phone Number', right_on='Phone Number')
#combined_ui_df = pd.merge(cafeteria_df, rec_center_df, left_index=True, right_index=True)
combined_ui_df = pd.merge(cafeteria_df, rec_center_df, on='Phone Number', how='outer')

# print combined UI DataFrames

combined_ui_df
# Out:
#       Phone Number List of Items Purchased  Unit Price  Quantity  \
# 0   (423)-365-3577                   Salad        10.0       1.0
# 1   (739)-663-5967               Hamburger         8.0       5.0
# 2   (174)-521-4921                    Taco         7.0       3.0
# 3   (320)-533-1447                 Burrito        10.0       3.0
# 4   (614)-981-5595               Hamburger        10.0       1.0
# 5   (682)-654-7361               Hamburger         7.0       1.0
# 6   (129)-938-3283                    Taco         5.0       3.0
# 7   (264)-687-3547                   Salad         7.0       5.0
# 8   (455)-902-6816                   Salad         7.0       5.0
# 9   (791)-357-8190                    Taco         7.0       5.0
# 10  (460)-411-1467                   Salad         5.0       3.0
# 11  (586)-648-6141               Hamburger         5.0       3.0
# 12  (253)-218-9518                 Burrito         7.0       2.0
# 13  (277)-450-7776         Chicken Tenders         5.0       4.0
# 14  (478)-764-3818               Hamburger         7.0       4.0
# 15  (478)-238-8738                   Salad         9.0       4.0
# 16  (219)-390-2393               Hamburger         9.0       4.0
# 17  (455)-536-4464                 Burrito         6.0       5.0
# 18  (982)-609-5718                    Taco         9.0       2.0
# 19  (510)-297-8485                   Salad        10.0       1.0
# 20  (955)-819-9922                     NaN         NaN       NaN
# 21  (887)-572-9653                     NaN         NaN       NaN
# 22  (105)-987-3843                     NaN         NaN       NaN
# 23  (476)-202-4752                     NaN         NaN       NaN
# 24  (884)-508-4845                     NaN         NaN       NaN
# 25  (223)-205-8929                     NaN         NaN       NaN
# 26  (436)-572-4110                     NaN         NaN       NaN
# 27  (662)-840-7886                     NaN         NaN       NaN
# 28  (819)-424-6154                     NaN         NaN       NaN
# 29  (986)-741-1202                     NaN         NaN       NaN
# 30  (716)-927-3683                     NaN         NaN       NaN
# 31  (696)-583-9066                     NaN         NaN       NaN
# 32  (885)-696-1758                     NaN         NaN       NaN
# 33  (754)-217-2349                     NaN         NaN       NaN
# 34  (989)-726-8760                     NaN         NaN       NaN
# 35  (881)-718-2930                     NaN         NaN       NaN
# 36  (740)-823-7811                     NaN         NaN       NaN
# 37  (413)-974-4496                     NaN         NaN       NaN
# 38  (734)-631-1000                     NaN         NaN       NaN
# 39  (725)-947-5830                     NaN         NaN       NaN
#
#    Date of Purchase Time of Each Purchase Date of Visit  \
# 0      May 16, 2022              05:32 PM           NaN
# 1      Sep 03, 2023              07:44 AM           NaN
# 2      Jun 24, 2023              11:11 AM           NaN
# 3      Apr 15, 2023              12:32 PM           NaN
# 4      Sep 29, 2021              08:04 PM           NaN
# 5      Jan 06, 2023              08:53 AM           NaN
# 6      Dec 06, 2023              01:46 PM           NaN
# 7      Apr 08, 2022              11:53 PM           NaN
# 8      Feb 11, 2023              12:00 AM           NaN
# 9      Nov 12, 2022              08:59 AM           NaN
# 10     Jun 04, 2021              07:50 PM           NaN
# 11     Sep 23, 2021              05:03 AM           NaN
# 12     Aug 14, 2020              11:21 AM           NaN
# 13     May 26, 2023              03:30 AM           NaN
# 14     Dec 07, 2022              07:03 PM           NaN
# 15     Jun 12, 2022              10:11 PM           NaN
# 16     Mar 20, 2020              11:16 PM           NaN
# 17     Aug 01, 2020              04:36 AM           NaN
# 18     Dec 26, 2021              11:20 PM           NaN
# 19     May 04, 2022              05:50 PM           NaN
# 20              NaN                   NaN  Nov 19, 2015
# 21              NaN                   NaN  Nov 29, 2018
# 22              NaN                   NaN  Jun 04, 2020
# 23              NaN                   NaN  Jan 30, 2014
# 24              NaN                   NaN  Mar 25, 2014
# 25              NaN                   NaN  Mar 08, 2019
# 26              NaN                   NaN  Mar 01, 2018
# 27              NaN                   NaN  May 17, 2017
# 28              NaN                   NaN  May 14, 2016
# 29              NaN                   NaN  Apr 03, 2016
# 30              NaN                   NaN  Jan 16, 2013
# 31              NaN                   NaN  Mar 07, 2021
# 32              NaN                   NaN  Nov 24, 2019
# 33              NaN                   NaN  Oct 10, 2018
# 34              NaN                   NaN  Mar 15, 2014
# 35              NaN                   NaN  Dec 04, 2013
# 36              NaN                   NaN  Jul 13, 2019
# 37              NaN                   NaN  Jun 01, 2018
# 38              NaN                   NaN  Sep 25, 2011
# 39              NaN                   NaN  Jun 14, 2011
#
#    Starting Time of Visit Ending Time of Visit
# 0                     NaN                  NaN
# 1                     NaN                  NaN
# 2                     NaN                  NaN
# 3                     NaN                  NaN
# 4                     NaN                  NaN
# 5                     NaN                  NaN
# 6                     NaN                  NaN
# 7                     NaN                  NaN
# 8                     NaN                  NaN
# 9                     NaN                  NaN
# 10                    NaN                  NaN
# 11                    NaN                  NaN
# 12                    NaN                  NaN
# 13                    NaN                  NaN
# 14                    NaN                  NaN
# 15                    NaN                  NaN
# 16                    NaN                  NaN
# 17                    NaN                  NaN
# 18                    NaN                  NaN
# 19                    NaN                  NaN
# 20               07:50 AM             06:32 PM
# 21               01:48 AM             01:49 AM
# 22               07:09 AM             11:47 PM
# 23               08:51 PM             10:44 AM
# 24               11:45 AM             08:29 PM
# 25               06:47 AM             08:50 PM
# 26               07:45 PM             07:13 AM
# 27               05:06 PM             09:33 PM
# 28               06:32 AM             06:05 AM
# 29               11:12 PM             07:12 AM
# 30               05:40 PM             03:53 AM
# 31               05:08 PM             05:16 AM
# 32               09:36 AM             09:40 PM
# 33               02:18 AM             09:46 AM
# 34               09:45 AM             07:29 AM
# 35               07:38 AM             01:43 PM
# 36               04:47 PM             12:22 AM
# 37               01:04 AM             03:45 PM
# 38               11:04 PM             06:45 PM
# 39               06:04 PM             03:19 AM

# %% [markdown]
# __Problem 4:__ The REC center wants to see the eating habits of its members to make food recommendation. Write the code to combine the data file for such purpose.

# %%
# create DataFrame that contains only the rows of REC center members who have eaten at the cafeteria

#rec_center_cafeteria_habits_df = combined_ui_df.dropna(how='any')
#rec_center_cafeteria_habits_df = pd.merge(cafeteria_df, rec_center_df, on='Phone Number', how='inner')
rec_center_cafeteria_habits_df = pd.merge(cafeteria_df, rec_center_df, on='Phone Number', how='right')

# print cafeteria habits of recenter
# this should print out rows in the REC center data frame but with empty cafeteria entries
# because no members of the REC center eat at the cafeteria

rec_center_cafeteria_habits_df
# Out:
#       Phone Number List of Items Purchased  Unit Price  Quantity  \
# 0   (955)-819-9922                     NaN         NaN       NaN
# 1   (887)-572-9653                     NaN         NaN       NaN
# 2   (105)-987-3843                     NaN         NaN       NaN
# 3   (476)-202-4752                     NaN         NaN       NaN
# 4   (884)-508-4845                     NaN         NaN       NaN
# 5   (223)-205-8929                     NaN         NaN       NaN
# 6   (436)-572-4110                     NaN         NaN       NaN
# 7   (662)-840-7886                     NaN         NaN       NaN
# 8   (819)-424-6154                     NaN         NaN       NaN
# 9   (986)-741-1202                     NaN         NaN       NaN
# 10  (716)-927-3683                     NaN         NaN       NaN
# 11  (696)-583-9066                     NaN         NaN       NaN
# 12  (885)-696-1758                     NaN         NaN       NaN
# 13  (754)-217-2349                     NaN         NaN       NaN
# 14  (989)-726-8760                     NaN         NaN       NaN
# 15  (881)-718-2930                     NaN         NaN       NaN
# 16  (740)-823-7811                     NaN         NaN       NaN
# 17  (413)-974-4496                     NaN         NaN       NaN
# 18  (734)-631-1000                     NaN         NaN       NaN
# 19  (725)-947-5830                     NaN         NaN       NaN
#
#    Date of Purchase Time of Each Purchase Date of Visit  \
# 0               NaN                   NaN  Nov 19, 2015
# 1               NaN                   NaN  Nov 29, 2018
# 2               NaN                   NaN  Jun 04, 2020
# 3               NaN                   NaN  Jan 30, 2014
# 4               NaN                   NaN  Mar 25, 2014
# 5               NaN                   NaN  Mar 08, 2019
# 6               NaN                   NaN  Mar 01, 2018
# 7               NaN                   NaN  May 17, 2017
# 8               NaN                   NaN  May 14, 2016
# 9               NaN                   NaN  Apr 03, 2016
# 10              NaN                   NaN  Jan 16, 2013
# 11              NaN                   NaN  Mar 07, 2021
# 12              NaN                   NaN  Nov 24, 2019
# 13              NaN                   NaN  Oct 10, 2018
# 14              NaN                   NaN  Mar 15, 2014
# 15              NaN                   NaN  Dec 04, 2013
# 16              NaN                   NaN  Jul 13, 2019
# 17              NaN                   NaN  Jun 01, 2018
# 18              NaN                   NaN  Sep 25, 2011
# 19              NaN                   NaN  Jun 14, 2011
#
#    Starting Time of Visit Ending Time of Visit
# 0                07:50 AM             06:32 PM
# 1                01:48 AM             01:49 AM
# 2                07:09 AM             11:47 PM
# 3                08:51 PM             10:44 AM
# 4                11:45 AM             08:29 PM
# 5                06:47 AM             08:50 PM
# 6                07:45 PM             07:13 AM
# 7                05:06 PM             09:33 PM
# 8                06:32 AM             06:05 AM
# 9                11:12 PM             07:12 AM
# 10               05:40 PM             03:53 AM
# 11               05:08 PM             05:16 AM
# 12               09:36 AM             09:40 PM
# 13               02:18 AM             09:46 AM
# 14               09:45 AM             07:29 AM
# 15               07:38 AM             01:43 PM
# 16               04:47 PM             12:22 AM
# 17               01:04 AM             03:45 PM
# 18               11:04 PM             06:45 PM
# 19               06:04 PM             03:19 AM

# %% [markdown]
# ## Part 2: working with external data
#
# __Problem:__ Read the "supermarket_data.csv" file. Read the names of the columns (nicely!). Then answer the following questions (basing on your detailed analysis/codes).

# %%
import pandas as pd

df = pd.read_csv("supermarket_data.csv")
df
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# 2        Home and lifestyle       46.33         7  16.2155   340.5255
# 3         Health and beauty       58.22         8  23.2880   489.0480
# 4         Sports and travel       86.31         7  30.2085   634.3785
# ..                      ...         ...       ...      ...        ...
# 995       Health and beauty       40.35         1   2.0175    42.3675
# 996      Home and lifestyle       97.38        10  48.6900  1022.4900
# 997      Food and beverages       31.84         1   1.5920    33.4320
# 998      Home and lifestyle       65.82         1   3.2910    69.1110
# 999     Fashion accessories       88.34         7  30.9190   649.2990
#
#           Date   Time      Payment    cogs  gross margin percentage  \
# 0     1/5/2019  13:08      Ewallet  522.83                 4.761905
# 1     3/8/2019  10:29         Cash   76.40                 4.761905
# 2     3/3/2019  13:23  Credit card  324.31                 4.761905
# 3    1/27/2019  20:33      Ewallet  465.76                 4.761905
# 4     2/8/2019  10:37      Ewallet  604.17                 4.761905
# ..         ...    ...          ...     ...                      ...
# 995  1/29/2019  13:46      Ewallet   40.35                 4.761905
# 996   3/2/2019  17:16      Ewallet  973.80                 4.761905
# 997   2/9/2019  13:22         Cash   31.84                 4.761905
# 998  2/22/2019  15:33         Cash   65.82                 4.761905
# 999  2/18/2019  13:28         Cash  618.38                 4.761905
#
#      gross income  Rating
# 0         26.1415     9.1
# 1          3.8200     9.6
# 2         16.2155     7.4
# 3         23.2880     8.4
# 4         30.2085     5.3
# ..            ...     ...
# 995        2.0175     6.2
# 996       48.6900     4.4
# 997        1.5920     7.7
# 998        3.2910     4.1
# 999       30.9190     6.6
#
# [1000 rows x 17 columns]

# %% [markdown]
# (a) What is the total gross income of each product line?

# %%
gross_income_by_product_line = df.groupby("Product line")["gross income"].sum()

print(gross_income_by_product_line)
# Out:
# Product line
# Electronic accessories    2587.5015
# Fashion accessories       2585.9950
# Food and beverages        2673.5640
# Health and beauty         2342.5590
# Home and lifestyle        2564.8530
# Sports and travel         2624.8965
# Name: gross income, dtype: float64

# %% [markdown]
# (b) What is the highest-rated product line in the dataset?

# %%
ratings_by_product_line = df.groupby("Product line")["Rating"].mean()
highest_rated_product = ratings_by_product_line.idxmax()

print(ratings_by_product_line)
print("\nHighest rated product line: %s" % highest_rated_product)
# Out:
# Product line
# Electronic accessories    6.924706
# Fashion accessories       7.029213
# Food and beverages        7.113218
# Health and beauty         7.003289
# Home and lifestyle        6.837500
# Sports and travel         6.916265
# Name: Rating, dtype: float64
#
# Highest rated product line: Food and beverages

# %% [markdown]
# (c) Which gender spend more money on Electronic accessories?

# %%
electronic_accessories_df = df[df["Product line"] == "Electronic accessories"]
electronic_accessories_sold_by_gender_df = electronic_accessories_df.groupby("Gender")["Total"].sum()
which_gender_buys_more = electronic_accessories_sold_by_gender_df.idxmax()

#print(electronic_accessories_df)
print(electronic_accessories_sold_by_gender_df)
print("\nWhich gender buys more electronic accessories: %s" %which_gender_buys_more)
# Out:
# Gender
# Female    27102.0225
# Male      27235.5090
# Name: Total, dtype: float64
#
# Which gender buys more electronic accessories: Male

# %% [markdown]
# (e) What month in the year that Health and beauty is most consumed?

# %%
# Create data frame with months column

months = []
for date in df["Date"]:
    data = str.split(date,'/')
    months.append(data[0])
#print(set(months))
df['Months'] = months

# Find month health and beauty product line was the most consumed

health_and_beauty_df = df[df["Product line"] == "Health and beauty"]
health_and_beauty_by_month_df = health_and_beauty_df.groupby("Months")["Total"].sum()
month_health_and_beauty_most_consumed = health_and_beauty_by_month_df.idxmax()

# Print tables and answer

#print(health_and_beauty_df)
print(health_and_beauty_by_month_df)
print("\nWhich month in the year is health and beauty most consumed: %s" %month_health_and_beauty_most_consumed)
# Out:
# Months
# 1    16383.1710
# 2    14602.2555
# 3    18208.3125
# Name: Total, dtype: float64
#
# Which month in the year is health and beauty most consumed: 3

# %% [markdown]
# (g) Study the relationships between the following quantities:'Unit price', 'Quantity', 'Tax 5%','cogs','gross margin percentage','gross income' (state at least three relationships and plot them).

# %%
import matplotlib.pyplot as plt

#(I): Unit Price and Gross Margin Percentage

plt.scatter(df["Unit price"], df["gross margin percentage"])
plt.xlabel("Unit Price")
plt.ylabel("Gross Margin Percentage")
plt.show()
print("Relationship: There is no correlation between the unit price and the gross margin percentage.")

#(II): Tax 5% and Costs of Goods Sold

plt.scatter(df["Tax 5%"], df["cogs"])
plt.xlabel("Tax 5%")
plt.ylabel("Costs of Goods Sold")
plt.show()
print("Relationship: There is a positive correlation between the tax being 5% and costs of goods sold.")

#(III): Tax 5% and Gross Margin Percentage

plt.scatter(df["Tax 5%"], df["gross margin percentage"])
plt.xlabel("Tax 5%")
plt.ylabel("Gross Margin Percentage")
plt.show()
print("Relationship: There is no correlation between the tax being 5% and the gross margin percentage.")

#(IV): Tax 5% and Gross Income

plt.scatter(df["Tax 5%"], df["gross income"])
plt.xlabel("Tax 5%")
plt.ylabel("Gross Income")
plt.show()
print("Relationship: There is a positive correlation between the tax being 5% and the gross income.")

#(V): Costs of Goods Sold and Gross Margin Percentage

plt.scatter(df["cogs"], df["gross margin percentage"])
plt.xlabel("Costs of Goods Sold")
plt.ylabel("Gross Margin Percentage")
plt.show()
print("Relationship: There is no correlation between the costs of goods sold and the gross margin percentage.")

#(VI): Costs of Goods Sold and Gross Income

plt.scatter(df["cogs"], df["gross income"])
plt.xlabel("Costs of Goods Sold")
plt.ylabel("Gross Income")
plt.show()
print("Relationship: There is a positive correlation between the costs of goods sold and the gross income.")

#(VI): Gross Income and Gross Margin Percentage

plt.scatter(df["gross income"], df["gross margin percentage"])
plt.xlabel("Gross Income")
plt.ylabel("Gross Margin Percentage")
plt.show()
print("Relationship: There is no correlation between the gross income and the gross margin percentage.")
# Out:
# Relationship: There is no correlation between the unit price and the gross margin percentage.
# Relationship: There is a positive correlation between the tax being 5% and costs of goods sold.
# Relationship: There is no correlation between the tax being 5% and the gross margin percentage.
# Relationship: There is a positive correlation between the tax being 5% and the gross income.
# Relationship: There is no correlation between the costs of goods sold and the gross margin percentage.
# Relationship: There is a positive correlation between the costs of goods sold and the gross income.
# Relationship: There is no correlation between the gross income and the gross margin percentage.
