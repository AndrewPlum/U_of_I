# %% [markdown]
# ***Andrew Plum***

# %% [markdown]
# ***MATH 183***

# %% [markdown]
# ***Assignment #7***

# %% [markdown]
# ***4/15/2023***

# %% [markdown]
# ## Part 1: Numpy and plotting

# %% [markdown]
# __Problem 1:__(3D plotting) Plot the function $f(x,y) = \cos(x*y)$, $(x,y) \in [-\pi,\pi] \times [-\pi,\pi]$ in three dimensional space.

# %%
# import packages

import numpy as np
import matplotlib.pyplot as plt

# initialize variables

x = np.linspace(-np.pi, np.pi, 100)
y = np.linspace(-np.pi, np.pi, 100)
X, Y = np.meshgrid(x,y)

# define function and assign data from it to varible Z

def f(x,y):
    return np.cos(X * Y)

Z = f(X, Y)

# plot in 3D

# %matplotlib notebook

fig = plt.figure()
ax = plt.axes(projection='3d')
ax.contour3D(X, Y, Z, 100, cmap='plasma')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# __Problem 2:__(Animation) Plot the function $f(x,t) = e^{-x^2+t}$ for $x \in [-3,3]$ and $t \in [0,2]$.

# %%
# import packages

import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
# %matplotlib notebook

# initialize variables x and t

x = np.linspace(-3, 3, 100)
t = np.linspace(0, 2, 100)

# define function and assign data from it to varible Z

def f(x, t):
    return np.exp(-x**2 + t)

# create figure and axes and set the axes limits

fig, ax = plt.subplots()
ax.set_xlim(-3, 3)
ax.set_ylim(0, 10)
line, = ax.plot([], [])

# define animate function

def animate(frame):
    line.set_data(x, f(x, frame))
    ax.set_title(f"t = {frame:.2f}") # display value of t (float) as animation title

# show animation

animation = FuncAnimation(fig, animate, frames=t, interval=100, blit=True)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Part 2: Final project description
#
# Describe your final project. Here is the instruction:
#
# __I. Statement of problem/dataset:__
#
# Clearly state the problem you want to solve (using data science skills) or dataset you want to explore. Describe the problem/dataset in details:
#
#  - If you work on __problem project__: describe how you have or will collect your data to solve your problem.
#
#  - If you work on the __dataset project__: describe your dataset (basic information, printing/viewing, basic visualization).
#
# __II. Literature review:__  of the problem/dataset that you want to work on:
#
#  - for problem project: (i) explain the origin of the problem (who proposed it to you or how/why you came up with it), and (ii) what has been done before.
#
#  - for dataset problem: (i) explain where do(es) the dataset(s) come from, and (ii) make proper refences to all the noticeable works on the dataset(s).
#
# __III. Working plan:__ Clear state your plan
#
# - What tasks/steps do you plan to carry out? State tentative timeline for each task/step.
#
# - What are the expected outcomes of the final project?
#
# __IV. Logistics and support received/needed:__
#
# - State any other things you want me to know. For example, if this is a team project: (i) clearly state your teammate and who will do what, (ii) how you will work together, (iii) why did you decide to work together.
#
# - State what support you will or have received from anyone else (not your teammate).
#
# - Let me know if you need any support from me. I will try to my best to support.

# %% [markdown]
# ### Answer:
#
# #### I.
#
# The project I have decided to do is a dataset project. I will be using labor market data collected by Lightcast as my dataset. Right now, I plan to look at data concerning data science jobs in the United States although I might look at data about other careers later. The data I have as part of my dataset right now lists things like job postings by location, some statistics on specific careers related to data science, and details of each job posting like the company advertising the job, the skills required for the job, the job title, the link to the posting if avaialabe, the job description etc. The data is tabular and stored in excel.
#
# #### II.
#
# The datasets are provided by the company Lightcast. The names of the four datasets I have in my possession right now are "Career_Pathways_655.xls", "Job_Postings_by_Location_Data_Scientists_in_United_States_4003.xls", "Job_Postings_List_490.xls", and "Job_Postings_List_9540.xls".
#
# #### III.
#
# I will first try to gain an understanding of the dataset by searching for trends in it. After I have gained an understanding, I will move onto visualizing the dataset. From there, I hope to move on to something more advanced for me and learn a machine learning method and apply it to the dataset. While doing all this I will be looking for key takeaways from the dataset and answer why this dataset is relevant. Since this is my first time doing a project like this, I hope to become more comfortable with data analysis by the end of the project.
#
# #### IV.
#
# I will be working on this project with a teammate. My project partner is Xavier Naranjo. As a starting point, I was planning on looking at other data analysis projects online to look for things that I could possibly do. We were planning on exploring the datasets for the first week by ourselves, and then meeting up to discuss what we've found. From there, we plan to work on visualizing the data set. Either the second last week or the last week before the project is due, we hope to learn and use some machine learning method or advanced data analysis technique. The whole time we will be documenting our findings.

# %% [markdown]
# ***Deadline for project:***
# 5/6/2023
