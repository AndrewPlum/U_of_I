# %% [markdown]
# ***Andrew Plum***

# %% [markdown]
# ***MATH 183***

# %% [markdown]
# ***Assignment #8***

# %% [markdown]
# ***4/23/2023***

# %% [markdown]
# __Problem 1:__ Let $\vec{v}=(\cos \pi/4, \sin \pi/4)$.

# %% [markdown]
# (a) Plot the function $f(x,y) = \cos((x,y) \cdot \vec{v})$ for $(x,y) \in [-2\pi, 2\pi] \times [-2\pi, 2\pi]$.

# %%
# import packages

import numpy as np
import matplotlib.pyplot as plt
from matplotlib import animation

# declare angle and v

angle = np.pi/4
v = np.array([np.cos(angle), np.sin(angle)])

# declare x and y and make meshgrid

x = np.linspace(-2*np.pi, 2*np.pi, 100)
y = np.linspace(-2*np.pi, 2*np.pi, 100)
X,Y = np.meshgrid(x,y)

dot = v[0]*X + v[1]*Y
f = np.cos(dot)
fig = plt.figure(figsize=(3,3))
plt.imshow(f)

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the vector v
v = np.array([np.cos(np.pi/4), np.sin(np.pi/4)])

# Define the function f
def f(x, y):
    return np.cos(np.dot([x, y], v))

# Create a grid of points over the domain [-2pi, 2pi] x [-2pi, 2pi]
x = np.linspace(-2*np.pi, 2*np.pi, 100)
y = np.linspace(-2*np.pi, 2*np.pi, 100)
X, Y = np.meshgrid(x, y)

# Evaluate the function f at each point on the grid
Z = f(X, Y)

# Create a 2D plot of the function values
plt.contourf(X, Y, Z, levels=20)
plt.colorbar()

# Add labels and a title
plt.xlabel('x')
plt.ylabel('y')
plt.title('f(x,y) = cos((x,y) dot v)')

# Display the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9640\55761956.py in <module>
#      15
#      16 # Evaluate the function f at each point on the grid
# ---> 17 Z = f(X, Y)
#      18
#      19 # Create a 2D plot of the function values
#
# ~\AppData\Local\Temp\ipykernel_9640\55761956.py in f(x, y)
#       7 # Define the function f
#       8 def f(x, y):
# ----> 9     return np.cos(np.dot([x, y], v))
#      10
#      11 # Create a grid of points over the domain [-2pi, 2pi] x [-2pi, 2pi]
#
# <__array_function__ internals> in dot(*args, **kwargs)
#
# ValueError: shapes (2,100,100) and (2,) not aligned: 100 (dim 2) != 2 (dim 0)

# %%
# import packages

import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# create v

v = np.array([np.cos(np.pi/4), np.sin(np.pi/4)])

# create function

def f(x,y):
    return np.cos(np.dot([x,y],v))

# declare x and y and make meshgrid

x = np.linspace(-2*np.pi, 2*np.pi, 200)
y = np.linspace(-2*np.pi, 2*np.pi, 200)
X, Y = np.meshgrid(x, y)

# evaluate Z

Z = np.zeros_like(X)
for i in range(len(x)):
    for j in range(len(y)):
        Z[i,j] = f(X[i,j],Y[i,j])

# plot function 

fig = plt.figure()
ax = fig.add_subplot(projection = "3d")
ax.plot_surface(X, Y, Z, cmap = "plasma")
ax.set_xlabel("x")
ax.set_ylabel("y")
ax.set_zlabel("f(x,y)")
plt.show()

# %% [markdown]
# (b) Plot the traveling wave function $f(x,y) = \cos((x,y) \cdot \vec{v}-t)$ for $(x,y) \in [-2\pi, 2\pi] \times [-2\pi, 2\pi]$ and $t \in [0,10]$.

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation

# Define the vector v
v = np.array([np.cos(np.pi/4), np.sin(np.pi/4)])

# Define the function f with time as an input
def f(x, y, t):
    return np.cos(np.dot([x, y], v) - t)

# Create a grid of points over the domain [-2pi, 2pi] x [-2pi, 2pi]
x = np.linspace(-2*np.pi, 2*np.pi, 100)
y = np.linspace(-2*np.pi, 2*np.pi, 100)
X, Y = np.meshgrid(x, y)

# Define the time range
t = np.linspace(0, 10, 100)

# Create the figure and axes
fig, ax = plt.subplots()

# Define the initial plot
im = ax.imshow(f(X, Y, 0), cmap='viridis', extent=[-2*np.pi, 2*np.pi, -2*np.pi, 2*np.pi])

# Define the update function for the animation
def update(i):
    im.set_data(f(X, Y, t[i]))
    return [im]

# Create the animation
anim = FuncAnimation(fig, update, frames=len(t), interval=50, blit=True)

# Add labels and a title
plt.xlabel('x')
plt.ylabel('y')
plt.title('Traveling Cosine Wave')

# Display the animation
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9640\3529669167.py in <module>
#      22
#      23 # Define the initial plot
# ---> 24 im = ax.imshow(f(X, Y, 0), cmap='viridis', extent=[-2*np.pi, 2*np.pi, -2*np.pi, 2*np.pi])
#      25
#      26 # Define the update function for the animation
#
# ~\AppData\Local\Temp\ipykernel_9640\3529669167.py in f(x, y, t)
#       8 # Define the function f with time as an input
#       9 def f(x, y, t):
# ---> 10     return np.cos(np.dot([x, y], v) - t)
#      11
#      12 # Create a grid of points over the domain [-2pi, 2pi] x [-2pi, 2pi]
#
# <__array_function__ internals> in dot(*args, **kwargs)
#
# ValueError: shapes (2,100,100) and (2,) not aligned: 100 (dim 2) != 2 (dim 0)

# %%
# NOTE: THIS MAY TAKE A WHILE TO RUN

# import packages

import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# create v

v = np.array([np.cos(np.pi/4), np.sin(np.pi/4)])

# declare x, y, and t and make meshgrid

x = np.linspace(-2*np.pi, 2*np.pi, 200)
y = np.linspace(-2*np.pi, 2*np.pi, 200)
t = np.linspace(0, 10, 200)
X, Y = np.meshgrid(x, y)

# initialize plot

fig = plt.figure()
ax = fig.add_subplot(projection = "3d")

# loop over t and plot for each step in t

for t_index in t:
    cos_arg = (X * v[0] + Y * v[1]) - t_index # calculate the cosine argument
    f = np.cos(cos_arg) # calculate values of function, store in f
    ax.plot_surface(X, Y, f, cmap = "plasma") # plot surface

# plot function    
   
ax.set_xlabel("x")
ax.set_ylabel("y")
ax.set_zlabel("f(x,y)")   
plt.show()

# %% [markdown]
# __Problem 2:__

# %% [markdown]
# (a) Load "retina" from skimage, and convert it into a grayscale image.

# %%
# import packages

from skimage import color, data, io

# load retina and convert to grayscale image

retina = data.retina()
retina_gray = color.rgb2gray(retina)
io.imshow(retina_gray)

# %% [markdown]
# (b) Plot its histogram

# %%
# import packages

import matplotlib.pyplot as plt

# show histogram

plt.hist(retina_gray.ravel(), bins = 100)
plt.title("Retina Histogram")
plt.show()

# %% [markdown]
# (c) Do thresholding for the image to turn all blood vessels into black (but try keep the rest as white)

# %%
# binarization

thresh = 0.34 # this is a manual estimate
binarized_retina = retina_gray > thresh
io.imshow(binarized_retina)

# %% [markdown]
# __Problem 3__

# %% [markdown]
# (a) Load shepp_logan_phantom from skimage

# %%
# import packages

from skimage import data, io

# load shepp_logan_phantom and show image

shepp_logan_phantom = data.shepp_logan_phantom()
io.imshow(shepp_logan_phantom)

# %% [markdown]
# (b) Use canny algorithm for detecting the edges in the image (play around with the parameters to make it looks good)

# %%
# import packages

from skimage.feature import canny

# use canny algorithm to find edges and show new image 

shepp_logan_phantom_edges_canny = canny(shepp_logan_phantom, sigma = 1)
# I've played with the parameters of canny and this the best I've gotten it to look
# changing the low_threshold and high_threshold erased edges in the image
io.imshow(shepp_logan_phantom_edges_canny)

# %% [markdown]
# (c) Generate a noisy version of the shepp_logan_phantom. Then denoise it using the Gaussian filter, median filter, and TV (Chambolle) method.

# %%
# import packages

from skimage import img_as_float
from skimage.util import random_noise
from skimage.filters import gaussian, median
from skimage.restoration import denoise_tv_chambolle
import matplotlib.pyplot as plt

# generate noisy version of shepp_logan_phantom

sigma = 0.25 # the higher the value the more corrupted
float_shepp_logan_phantom = img_as_float(shepp_logan_phantom) # needs a conversion for the arrays to be stored as float
noisy_shepp_logan_phantom = random_noise(float_shepp_logan_phantom, var = sigma**2)
plt.subplot(141)
plt.title("Noisy Image")
io.imshow(noisy_shepp_logan_phantom)

# denoise using gaussian filter

gaussian_denoised_shepp_logan_phantom = gaussian(noisy_shepp_logan_phantom, sigma=1)
plt.subplot(142)
plt.title("Gaussian Filter")
io.imshow(gaussian_denoised_shepp_logan_phantom)

# denoise using median filter

median_denoised_shepp_logan_phantom = median(noisy_shepp_logan_phantom)
plt.subplot(143)
plt.title("Median Filter")
io.imshow(median_denoised_shepp_logan_phantom)

# denoise using TV Chambolle method

tv_denoised_shepp_logan_phantom = denoise_tv_chambolle(noisy_shepp_logan_phantom, weight=0.1)
plt.subplot(144)
plt.title("TV Chambolle")
io.imshow(tv_denoised_shepp_logan_phantom)
