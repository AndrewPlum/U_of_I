# %%
# Read csv file 

import pandas as pd
df = pd.read_csv("supermarket_data.csv") # you get this say from the internet
df # output the dataframe possibly
df.head(10) # prints the first 10
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
# 5  699-14-3026      C  Naypyitaw        Normal    Male
# 6  355-53-5943      A     Yangon        Member  Female
# 7  315-22-5665      C  Naypyitaw        Normal  Female
# 8  665-32-9167      A     Yangon        Member  Female
# 9  692-92-5582      B   Mandalay        Member  Female
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# ...

# %%
# DataFrame help
# Use help to learn more about dataframe functions

# %%
# DataFrame info

print(df.info)
# Out:
# <bound method DataFrame.info of       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
# DataFrame describe
# Describes the dataframe with statistics
# Can't descirbe object data, only number data

print(df.describe())
# Out:
#         Unit price     Quantity       Tax 5%        Total        cogs  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.00000
# mean     55.672130     5.510000    15.379369   322.966749   307.58738
# std      26.494628     2.923431    11.708825   245.885335   234.17651
# min      10.080000     1.000000     0.508500    10.678500    10.17000
# 25%      32.875000     3.000000     5.924875   124.422375   118.49750
# 50%      55.230000     5.000000    12.088000   253.848000   241.76000
# 75%      77.935000     8.000000    22.445250   471.350250   448.90500
# max      99.960000    10.000000    49.650000  1042.650000   993.00000
#
#        gross margin percentage  gross income      Rating
# count             1.000000e+03   1000.000000  1000.00000
# mean              4.761905e+00     15.379369     6.97270
# std               6.131498e-14     11.708825     1.71858
# min               4.761905e+00      0.508500     4.00000
# ...

# %%
# DataFrame 

import pandas as pd

# Creating a sample dataframe
edf = pd.DataFrame({"A" : ["foo", "bar", "foo", "bar"],
                   "B" : ["one", "one", "two", "one"],
                   "C" : [1, 2, 3, 4],
                   "D" : [10, 20, 30, 40]})

# Grouping the dataframe by columns "A"
grouped = edf.groupby(["A"])

# Grouping the dataframe by columns "A" and "B"
#grouped = edf.groupby(["A, "B"])

# Calculating the sum of the values in columns 'C' and 'D' for each group
result = grouped.sum()

print(df)
print("Grouped result:")
print(result)
# Out:
#      A    B  C   D
# 0  foo  one  1  10
# 1  bar  one  2  20
# 2  foo  two  3  30
# 3  bar  one  4  40
# Grouped result:
#      C   D
# A
# bar  6  60
# foo  4  40

# %%
# Print col

# %%
#pip install matplotlib # previously already installed
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# Plot a line

import matplotlib.pyplot as plt

plt.scatter(df["Unit price"], df["Tax 5%"])
plt.xlabel("Unit price")
plt.ylabel("Tax 5%")
plt.show()

# %%
# List all the unique values in the Column city

df["City"].unique()
# Out:
# array(['Yangon', 'Naypyitaw', 'Mandalay'], dtype=object)

# %%
# Extract the data from "Yangon"

Yangon_df = df.loc[df["City"] == "Yangon"]
Yangon_df
# Out:
#       Invoice ID Branch    City Customer type  Gender            Product line  \
# 0    750-67-8428      A  Yangon        Member  Female       Health and beauty
# 2    631-41-3108      A  Yangon        Normal    Male      Home and lifestyle
# 3    123-19-1176      A  Yangon        Member    Male       Health and beauty
# 4    373-73-7910      A  Yangon        Normal    Male       Sports and travel
# 6    355-53-5943      A  Yangon        Member  Female  Electronic accessories
# ..           ...    ...     ...           ...     ...                     ...
# 990  886-18-2897      A  Yangon        Normal  Female      Food and beverages
# 992  745-74-0715      A  Yangon        Normal    Male  Electronic accessories
# 997  727-02-1313      A  Yangon        Member    Male      Food and beverages
# 998  347-56-2442      A  Yangon        Normal    Male      Home and lifestyle
# 999  849-09-3807      A  Yangon        Member  Female     Fashion accessories
#
# ...

# %%
# Plot a line of Yangon data

import matplotlib.pyplot as plt

plt.scatter(Yangon_df["Unit price"], Yangon_df["Tax 5%"])
plt.xlabel("Unit price")
plt.ylabel("Tax 5%")
plt.show()

# %%
# List all the unique values in the Column product line

df["Product line"].unique()
# Out:
# array(['Health and beauty', 'Electronic accessories',
#        'Home and lifestyle', 'Sports and travel', 'Food and beverages',
#        'Fashion accessories'], dtype=object)

# %%
#Extract health and beauty data

hb_df = df.loc[df["Product line"] == "Health adn beauty"]
hb_df
# Out:
# Empty DataFrame
# Columns: [Invoice ID, Branch, City, Customer type, Gender, Product line, Unit price, Quantity, Tax 5%, Total, Date, Time, Payment, cogs, gross margin percentage, gross income, Rating]
# Index: []

# %%
# Plot a line of health and beauty data

import matplotlib.pyplot as plt

plt.scatter(hb_df["Unit price"], hb_df["Tax 5%"])
plt.xlabel("Unit price")
plt.ylabel("Tax 5%")
plt.show()

# %% [markdown]
# __Practice Problems:__ Open the file "supermarket_data.csv" using Pandas.
#
# (a) Compute the mean value of other quantity basing on 'City'.
#
# (b) Make a scatter plot on Quantity and Unit price.

# %%
# Practice Problem a:

# ANSWER TO CHECK OUT TICKET 1 a

new_groupded = df.groupby(['City'])
#new_groupded
new_groupded.mean()
# Out:
#            Unit price  Quantity     Tax 5%       Total        cogs  \
# City
# Mandalay    55.659277  5.481928  15.232024  319.872506  304.640482
# Naypyitaw   56.609024  5.582317  16.052367  337.099715  321.047348
# Yangon      54.780853  5.467647  14.874001  312.354031  297.480029
#
#            gross margin percentage  gross income    Rating
# City
# Mandalay                  4.761905     15.232024  6.818072
# Naypyitaw                 4.761905     16.052367  7.072866
# Yangon                    4.761905     14.874001  7.027059

# %%
# Practice Problem b:

# ANSWER TO CHECK OUT TICKET 1 b

import matplotlib.pyplot as plt

plt.scatter(df["Quantity"], df["Unit price"])
plt.xlabel("Quantity")
plt.ylabel("Unit price")
# Out:
# Text(0, 0.5, 'Unit price')

# %%
# ANSWER TO CHECK OUT TICKET 1 c
# Get the slopes?

tax = df["Tax 5%"]
up = df["Unit price"]
conj = df["Unit price"]*df["Quantity"]*0.05
#print(conj)
r = tax/conj
uniq = r.unique()
print(uniq[0])
print(uniq[1])
print(uniq[2])
print(uniq[3])
#len(r.unique())
# Out:
# 1.0000000000000002
# 1.0
# 0.9999999999999998
# 0.9999999999999999

# %%
# ANSWER TO CHECK OUT TICKET 1 d

mr = r[1]
print(mr)
# Out:
# 0.25

# %%
# ANSWER TO CHECK OUT TICKET 1 e

sdf = df.loc[r == mr]
#sdf

for col in df.columns:
    print(col, len(sdf[col].unique()))
# Out:
# Invoice ID 102
# Branch 3
# City 3
# Customer type 2
# Gender 2
# Product line 6
# Unit price 102
# Quantity 1
# Tax 5% 102
# Total 102
# Date 65
# Time 96
# Payment 3
# cogs 102
# gross margin percentage 1
# gross income 102
# Rating 49
