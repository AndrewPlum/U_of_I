# %% [markdown]
# ## 2D vs 3D ploting
#
# We can plot a function $z = f(x,y)$ in three dimensional space.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# __Problem:__ Plot the function $f(x,y) = \sin(\sqrt{x^2+y^2})$ in the square $[-6,6] \times [-6,6]$.

# %%
# Define the function we want to plot 

# Generate the domain of your function
x = np.linspace(-6, 6, 100)
y = np.linspace(-6, 6, 100)
X, Y = np.meshgrid(x,y)

# Generate your data
def f(x,y):
    return np.sin(np.sqrt(x**2+y**2))

Z = f(X, Y)
Z.shape
# Out:
# (100, 100)

# %%
# 2D plot with colorbar 

plt.figure(figsize = (3,3))
plt.imshow(Z,cmap='plasma') #cmap stands for color map - can do viridis, reds, plasma, etc
plt.colorbar() # the color bar will be between 0 and 1 because of the sin function
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="300">

# %%
# 3D plot using contour 

# %matplotlib notebook

fig = plt.figure(figsize=(3,3))
ax = plt.axes(projection='3d')

#note: play around with color map
ax.contour3D(X, Y, Z, 100, cmap='plasma') # contour stays at the same z value
# Out:
# <img src="data:image/png;base64,..." width="300">

# %%
# 3D plot using surface 
plt.figure(figsize = (3,3))
ax2 = plt.axes(projection='3d')

ax2.plot_surface(X,Y,Z, cmap = "plasma")
# Out:
# <img src="data:image/png;base64,..." width="299.99999349767523">

# %% [markdown]
# __Practice:__ Plot the function $f(x,y) = (x-1)^2+(y-1)^2 + (x+1)^2+(y+1)^2$ on the square $[-3,3] \times [-3,3]$.

# %%
x = np.linspace(-3,3,100) 
y = np.linspace(-3,3,100)
X, Y = np.meshgrid(x,y)

def f(x,y):
    return ((x-1)**2+(y-1)**2+(x+1)**2+(y+1)**2)

Z = f(X,Y)

plt.figure(figsize = (3,3))
plt.imshow(Z,cmap='plasma') #cmap stands for color map - can do viridis, reds, plasma, etc
plt.colorbar() # the color bar will be between 0 and 1 because of the sin function
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="299.99999349767523">

# %%
# 3D plot using contour 

# %matplotlib notebook

fig = plt.figure(figsize=(3,3))
ax = plt.axes(projection='3d')

#note: play around with color map
ax.contour3D(X, Y, Z, 100, cmap='plasma') # contour stays at the same z value
# Out:
# <img src="data:image/png;base64,..." width="299.99999349767523">

# %%
# 3D plot using surface 
plt.figure(figsize = (3,3))
ax2 = plt.axes(projection='3d')

ax2.plot_surface(X,Y,Z, cmap = "plasma")
# Out:
# <img src="data:image/png;base64,..." width="299.99999349767523">

# %% [markdown]
# ## Time depedent plotting

# %% [markdown]
# __Problem:__ Given the function $f(x,t) = \sin(x+t)$ for $x \in [-\pi,\pi]$ and $t \in [0,2 \pi]$. Plot the function $f$ in time.

# %%
from numpy import pi
x = np.linspace(-pi,pi,100)
t = np.linspace(0,2*pi,50)

# Generate the meshgrid and function
X,T = np.meshgrid(x,t)

plt.figure(figsize=(3,3))
Z = np.sin(X+T) # can also define using function definition
plt.imshow(Z)

# %%
# Static plots

plt.figure(figsize=(3,3))
plt.plot(Z[0])
plt.show()

plt.figure(figsize=(3,3))
plt.plot(Z[25])
plt.show()

# %%
#Dynamic plot - animation
from matplotlib import animation

# First set up the figure, the axis, and the plot element we want to  animate
fig = plt.figure(figsize=(3,3))
ax = plt.axes(xlim=(-np.pi, np.pi), ylim=(-2, 2))

#plot the intial function
line, = ax.plot([], [], lw=2)

# animation function.  This is called sequentially

def animate(i):
    x = np.linspace(-np.pi, np.pi, 100)
    y = Z[i]
    line.set_data(x,y)
    return line

anim = animation.FuncAnimation(fig, animate,
                           frames=200, interval=30, blit=True)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_24812\1913700080.py in <module>
#      17     return line
#      18
# ---> 19 anim = animation.FuncAnimation(fig, animate,
#      20                            frames=200, interval=30, blit=True)
#
# ~\anaconda3\lib\site-packages\matplotlib\animation.py in __init__(self, fig, func, frames, init_func, fargs, save_count, cache_frame_data, **kwargs)
#    1632         self._save_seq = []
#    1633
# -> 1634         super().__init__(fig, **kwargs)
#    1635
#    1636         # Need to reset the saved seq, since right now it will contain data
#
# ~\anaconda3\lib\site-packages\matplotlib\animation.py in __init__(self, fig, interval, repeat_delay, repeat, event_source, *args, **kwargs)
#    1394         if event_source is None:
# ...

# %% [markdown]
# THIS WAS THE PROBLEM FROM ABOVE - FOR COMPARISON
# __Problem:__ Given the function $f(x,t) = \sin(x+t)$ for $x \in [-\pi,\pi]$ and $t \in [0,2 \pi]$. Plot the function $f$ in time.

# %% [markdown]
# __Practice:__ Plot the function $f(x,t) = e^{-x^2+t}$ for $x \in [-3,3]$ and $t \in [0,2]$.

# %%
# 3D animation
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Create the data for the spiral
t = np.linspace(0, 10*np.pi, 1000)
x = np.sin(t)
y = np.cos(t)
z = t

# Create a figure and 3D axes
fig = plt.figure()
ax = plt.axes(projection='3d')

# Create an initial plot of the spiral
def f():
    return 2.1**(-(x**2)+t)

# Define the animation function
def animate(i):
    x = np.linspace(-pi, pi, 100)
    y = Z[i]
    line.set_data(x,y)
    return line

# Create the animation object
ani = animation.FuncAnimation(fig, animate, frames=360, interval=50)

# Show the animation
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_25364\1218008603.py in <module>
#      26
#      27 # Create the animation object
# ---> 28 ani = animation.FuncAnimation(fig, animate, frames=360, interval=50)
#      29
#      30 # Show the animation
#
# NameError: name 'animation' is not defined

# %% [markdown]
# __Practice:__ Change the plot to the curve $x = tsin(t), y =  t cos(t), z = t$.
