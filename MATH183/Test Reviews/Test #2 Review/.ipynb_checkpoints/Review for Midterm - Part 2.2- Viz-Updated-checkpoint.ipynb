# %% [markdown]
# ## Visualization
#
# ### Packages:
#
# - Matplotlib
#
# - Seaborn
#
# - Pandas
#
# NOTE: I will go over the syntax for each plot below.

# %% [markdown]
# __Probem 1:__ Read the data from the file "Simplified order.csv" as a DataFrames named df_orders.

# %%
import pandas as pd
#path = 'raw data MBAs/'
#df_orders = pd.read_csv(path+'Simplified orders.csv')
df_orders = pd.read_csv('Simplified orders.csv')

# %% [markdown]
# (a) Plot the histogram of the columns DRINKS using Mathplotlib, Seaborn, and Pandas, respectively. NOTE: you may want to take log scale to make it look nice.
#
# #### Histogram
#  - Matplotlib:
#     ```Python
#      plt.hist(data)
#     ```
#     Here,
#       - plt stands for matplotlib.pylot
#       - data: an array that contains values
#  - Seaborn:
#      ```Python
#      sns.barplot(data)
#      ```
#    Here,
#       - sns stands for seaborn
#       - data is an array that contains values
#
#  - Pandas:
#      ```Python
#     df.plot(kind = 'hist', column= column_name)
#     ```
#     Here,
#       - df stands for a DataFrame
#       - column_name is the name of column that has the data

# %%
import matplotlib.pyplot as plt
plt.hist(df_orders['DRINKS'],log=True, bins = 23)
plt.show()

# %%
import seaborn as sns
sns.histplot(df_orders['DRINKS'],log=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11468\1159672440.py in <module>
#       1 import seaborn as sns
# ----> 2 sns.histplot(df_orders['DRINKS'],log=True)
#
# ~\anaconda3\lib\site-packages\seaborn\distributions.py in histplot(data, x, y, hue, weights, stat, bins, binwidth, binrange, discrete, cumulative, common_bins, common_norm, multiple, element, fill, shrink, kde, kde_kws, line_kws, thresh, pthresh, pmax, cbar, cbar_ax, cbar_kws, palette, hue_order, hue_norm, color, log_scale, legend, ax, **kwargs)
#    1460     if p.univariate:
#    1461
# -> 1462         p.plot_univariate_histogram(
#    1463             multiple=multiple,
#    1464             element=element,
#
# ~\anaconda3\lib\site-packages\seaborn\distributions.py in plot_univariate_histogram(self, multiple, element, fill, common_norm, common_bins, shrink, kde, kde_kws, color, legend, line_kws, estimate_kws, **plot_kws)
#     514                         artist = mpl.patches.Rectangle
#     515                         plot_kws = _normalize_kwargs(plot_kws, artist)
# --> 516                         scout = self.ax.fill_between([], [], color=color, **plot_kws)
#     517                         default_color = tuple(scout.get_facecolor().squeeze())
#     518                 else:
#
# ~\anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1410     def inner(ax, *args, data=None, **kwargs):
#    1411         if data is None:
# -> 1412             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1413
#    1414         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py in fill_between(self, x, y1, y2, where, interpolate, step, **kwargs)
#    5243     def fill_between(self, x, y1, y2=0, where=None, interpolate=False,
#    5244                      step=None, **kwargs):
# -> 5245         return self._fill_between_x_or_y(
#    5246             "x", x, y1, y2,
#    5247             where=where, interpolate=interpolate, step=step, **kwargs)
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py in _fill_between_x_or_y(self, ind_dir, ind, dep1, dep2, where, interpolate, step, **kwargs)
#    5229             polys.append(pts)
#    5230
# -> 5231         collection = mcoll.PolyCollection(polys, **kwargs)
#    5232
#    5233         # now update the datalim and autoscale
#
# ~\anaconda3\lib\site-packages\matplotlib\collections.py in __init__(self, verts, sizes, closed, **kwargs)
#    1184             Forwarded to `.Collection`.
#    1185         """
# -> 1186         super().__init__(**kwargs)
#    1187         self.set_sizes(sizes)
#    1188         self.set_verts(verts, closed)
#
# ~\anaconda3\lib\site-packages\matplotlib\collections.py in __init__(self, edgecolors, facecolors, linewidths, linestyles, capstyle, joinstyle, antialiaseds, offsets, transOffset, norm, cmap, pickradius, hatch, urls, zorder, **kwargs)
#     215
#     216         self._path_effects = None
# --> 217         self.update(kwargs)
#     218         self._paths = None
#     219
#
# ~\anaconda3\lib\site-packages\matplotlib\artist.py in update(self, props)
#    1062                     func = getattr(self, f"set_{k}", None)
#    1063                     if not callable(func):
# -> 1064                         raise AttributeError(f"{type(self).__name__!r} object "
#    1065                                              f"has no property {k!r}")
#    1066                     ret.append(func(v))
#
# AttributeError: 'PolyCollection' object has no property 'log'

# %%
import numpy as np
df_orders.plot(kind='hist',column = 'DRINKS', bins= 23, logy=True)

# %% [markdown]
# (b) Plot the number of drinks sold each date as a line chart.
#
# #### Line plot/chart:
#
#  - Matplotlib:
#     ```Python
#      plt.plot(xdata,ydata)
#     ```
#     Here,
#       - plt stands for matplotlib.pylot
#       - xdata: an array that contains x values
#       - ydata: an array that contains y values
#       - NOTE: you can input ONE data array instead, then it is the ydata array.
#
#
#  - Seaborn:
#      ```Python
#      sns.lineplot(x=xdata,y=ydata)
#      ```
#    Here,
#       - sns stands for seaborn
#       - xdata is an array that contains x values
#       - ydata is an array that contains y values
#       - NOTE: if you only has one array (ydata) and plot its values as a line chart, then the syntax is
#     ```Python
#      sns.lineplot(ydata)
#      ```
#
#  - Pandas:
#      ```Python
#     df.plot(kind = 'line', x= columnx, y = columny)
#     ```
#     Here,
#       - df stands for a DataFrame
#       - columnx, columy are the names of the columns of x and y data, respectively.
#       - if df is a Series (one column of data), then the syntax is:
#      ```Python
#     df.plot(kind = 'line')
#     ```

# %%
df_orders['DATE'] = pd.to_datetime(df_orders['DATETIME']).dt.date
df_sum_drinks = df_orders.groupby('DATE')['DRINKS'].sum()

# %%
type(df_sum_drinks)
#plt.plot(df_sum_drinks.index,df_sum_drinks.values)
# Out:
# pandas.core.series.Series

# %%
sns.lineplot(df_sum_drinks.values)
# Out:
# C:\Users\plumz\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\plumz\anaconda3\lib\site-packages\numpy\lib\nanfunctions.py:1374: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(
# C:\Users\plumz\anaconda3\lib\site-packages\numpy\lib\nanfunctions.py:1374: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(
# C:\Users\plumz\anaconda3\lib\site-packages\numpy\lib\nanfunctions.py:1374: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(
# C:\Users\plumz\anaconda3\lib\site-packages\numpy\lib\nanfunctions.py:1374: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(
# C:\Users\plumz\anaconda3\lib\site-packages\numpy\lib\nanfunctions.py:1374: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(
# C:\Users\plumz\anaconda3\lib\site-packages\numpy\lib\nanfunctions.py:1374: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(
# C:\Users\plumz\anaconda3\lib\site-packages\numpy\lib\nanfunctions.py:1374: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(
# C:\Users\plumz\anaconda3\lib\site-packages\numpy\lib\nanfunctions.py:1374: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(
# C:\Users\plumz\anaconda3\lib\site-packages\numpy\lib\nanfunctions.py:1374: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(
# C:\Users\plumz\anaconda3\lib\site-packages\numpy\lib\nanfunctions.py:1374: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(
# C:\Users\plumz\anaconda3\lib\site-packages\numpy\lib\nanfunctions.py:1374: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(
# C:\Users\plumz\anaconda3\lib\site-packages\numpy\lib\nanfunctions.py:1374: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(
# C:\Users\plumz\anaconda3\lib\site-packages\numpy\lib\nanfunctions.py:1374: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(
# C:\Users\plumz\anaconda3\lib\site-packages\numpy\lib\nanfunctions.py:1374: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(
# C:\Users\plumz\anaconda3\lib\site-packages\numpy\lib\nanfunctions.py:1374: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(
# C:\Users\plumz\anaconda3\lib\site-packages\numpy\lib\nanfunctions.py:1374: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(
# C:\Users\plumz\anaconda3\lib\site-packages\numpy\lib\nanfunctions.py:1374: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(
# C:\Users\plumz\anaconda3\lib\site-packages\numpy\lib\nanfunctions.py:1374: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(
# C:\Users\plumz\anaconda3\lib\site-packages\numpy\lib\nanfunctions.py:1374: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(
# C:\Users\plumz\anaconda3\lib\site-packages\numpy\lib\nanfunctions.py:1374: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(
# C:\Users\plumz\anaconda3\lib\site-packages\numpy\lib\nanfunctions.py:1374: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(
# C:\Users\plumz\anaconda3\lib\site-packages\numpy\lib\nanfunctions.py:1374: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(
# C:\Users\plumz\anaconda3\lib\site-packages\numpy\lib\nanfunctions.py:1374: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(
# C:\Users\plumz\anaconda3\lib\site-packages\numpy\lib\nanfunctions.py:1374: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(
# C:\Users\plumz\anaconda3\lib\site-packages\numpy\lib\nanfunctions.py:1374: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(
# C:\Users\plumz\anaconda3\lib\site-packages\numpy\lib\nanfunctions.py:1374: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(
# C:\Users\plumz\anaconda3\lib\site-packages\numpy\lib\nanfunctions.py:1374: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(
# C:\Users\plumz\anaconda3\lib\site-packages\numpy\lib\nanfunctions.py:1374: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(
# C:\Users\plumz\anaconda3\lib\site-packages\numpy\lib\nanfunctions.py:1374: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(
# C:\Users\plumz\anaconda3\lib\site-packages\numpy\lib\nanfunctions.py:1374: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(
# C:\Users\plumz\anaconda3\lib\site-packages\numpy\lib\nanfunctions.py:1374: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(
# C:\Users\plumz\anaconda3\lib\site-packages\numpy\lib\nanfunctions.py:1374: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(
# C:\Users\plumz\anaconda3\lib\site-packages\numpy\lib\nanfunctions.py:1374: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(
# C:\Users\plumz\anaconda3\lib\site-packages\numpy\lib\nanfunctions.py:1374: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(
# C:\Users\plumz\anaconda3\lib\site-packages\numpy\lib\nanfunctions.py:1374: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(
# C:\Users\plumz\anaconda3\lib\site-packages\numpy\lib\nanfunctions.py:1374: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(
# C:\Users\plumz\anaconda3\lib\site-packages\numpy\lib\nanfunctions.py:1374: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(
# C:\Users\plumz\anaconda3\lib\site-packages\numpy\lib\nanfunctions.py:1374: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(
# C:\Users\plumz\anaconda3\lib\site-packages\numpy\lib\nanfunctions.py:1374: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(
# C:\Users\plumz\anaconda3\lib\site-packages\numpy\lib\nanfunctions.py:1374: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(
# C:\Users\plumz\anaconda3\lib\site-packages\numpy\lib\nanfunctions.py:1374: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(
# C:\Users\plumz\anaconda3\lib\site-packages\numpy\lib\nanfunctions.py:1374: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(
# C:\Users\plumz\anaconda3\lib\site-packages\numpy\lib\nanfunctions.py:1374: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(
# C:\Users\plumz\anaconda3\lib\site-packages\numpy\lib\nanfunctions.py:1374: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(
# C:\Users\plumz\anaconda3\lib\site-packages\numpy\lib\nanfunctions.py:1374: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(
# C:\Users\plumz\anaconda3\lib\site-packages\numpy\lib\nanfunctions.py:1374: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(
# C:\Users\plumz\anaconda3\lib\site-packages\numpy\lib\nanfunctions.py:1374: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(
# C:\Users\plumz\anaconda3\lib\site-packages\numpy\lib\nanfunctions.py:1374: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(
# C:\Users\plumz\anaconda3\lib\site-packages\numpy\lib\nanfunctions.py:1374: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(
# C:\Users\plumz\anaconda3\lib\site-packages\numpy\lib\nanfunctions.py:1374: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(
# C:\Users\plumz\anaconda3\lib\site-packages\numpy\lib\nanfunctions.py:1374: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(
# C:\Users\plumz\anaconda3\lib\site-packages\numpy\lib\nanfunctions.py:1374: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(
# C:\Users\plumz\anaconda3\lib\site-packages\numpy\lib\nanfunctions.py:1374: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(
# C:\Users\plumz\anaconda3\lib\site-packages\numpy\lib\nanfunctions.py:1374: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(
# C:\Users\plumz\anaconda3\lib\site-packages\numpy\lib\nanfunctions.py:1374: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(
# C:\Users\plumz\anaconda3\lib\site-packages\numpy\lib\nanfunctions.py:1374: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(
# C:\Users\plumz\anaconda3\lib\site-packages\numpy\lib\nanfunctions.py:1374: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(
# C:\Users\plumz\anaconda3\lib\site-packages\numpy\lib\nanfunctions.py:1374: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(
# C:\Users\plumz\anaconda3\lib\site-packages\numpy\lib\nanfunctions.py:1374: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(
# C:\Users\plumz\anaconda3\lib\site-packages\numpy\lib\nanfunctions.py:1374: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(
# C:\Users\plumz\anaconda3\lib\site-packages\numpy\lib\nanfunctions.py:1374: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(
# C:\Users\plumz\anaconda3\lib\site-packages\numpy\lib\nanfunctions.py:1374: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(
# C:\Users\plumz\anaconda3\lib\site-packages\numpy\lib\nanfunctions.py:1374: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(
# C:\Users\plumz\anaconda3\lib\site-packages\numpy\lib\nanfunctions.py:1374: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(
# C:\Users\plumz\anaconda3\lib\site-packages\numpy\lib\nanfunctions.py:1374: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(
# C:\Users\plumz\anaconda3\lib\site-packages\numpy\lib\nanfunctions.py:1374: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(
# C:\Users\plumz\anaconda3\lib\site-packages\numpy\lib\nanfunctions.py:1374: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(
# C:\Users\plumz\anaconda3\lib\site-packages\numpy\lib\nanfunctions.py:1374: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(
# C:\Users\plumz\anaconda3\lib\site-packages\numpy\lib\nanfunctions.py:1374: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(
# C:\Users\plumz\anaconda3\lib\site-packages\numpy\lib\nanfunctions.py:1374: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(
# C:\Users\plumz\anaconda3\lib\site-packages\numpy\lib\nanfunctions.py:1374: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(
# C:\Users\plumz\anaconda3\lib\site-packages\numpy\lib\nanfunctions.py:1374: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(
# C:\Users\plumz\anaconda3\lib\site-packages\numpy\lib\nanfunctions.py:1374: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(
# C:\Users\plumz\anaconda3\lib\site-packages\numpy\lib\nanfunctions.py:1374: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(
# C:\Users\plumz\anaconda3\lib\site-packages\numpy\lib\nanfunctions.py:1374: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(
# C:\Users\plumz\anaconda3\lib\site-packages\numpy\lib\nanfunctions.py:1374: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(
# C:\Users\plumz\anaconda3\lib\site-packages\numpy\lib\nanfunctions.py:1374: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(
# C:\Users\plumz\anaconda3\lib\site-packages\numpy\lib\nanfunctions.py:1374: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(
# C:\Users\plumz\anaconda3\lib\site-packages\numpy\lib\nanfunctions.py:1374: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(
# C:\Users\plumz\anaconda3\lib\site-packages\numpy\lib\nanfunctions.py:1374: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(
# C:\Users\plumz\anaconda3\lib\site-packages\numpy\lib\nanfunctions.py:1374: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(
# C:\Users\plumz\anaconda3\lib\site-packages\numpy\lib\nanfunctions.py:1374: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(
# C:\Users\plumz\anaconda3\lib\site-packages\numpy\lib\nanfunctions.py:1374: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(
# C:\Users\plumz\anaconda3\lib\site-packages\numpy\lib\nanfunctions.py:1374: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(
# <AxesSubplot:>

# %%
df_sum_drinks.plot(kind='line')
# Out:
# <AxesSubplot:xlabel='DATE'>

# %% [markdown]
# (c) Barplot for sum of drinks per month.
#
# #### Bar plot
#
#  - Matplotlib:
#     ```Python
#      plt.bar(xdata,ydata)
#     ```
#     Here,
#       - plt stands for matplotlib.pylot
#       - xdata: an array that contains x values
#       - ydata: an array that contains y values
#  - Seaborn:
#      ```Python
#      sns.barplot(x=xdata,y=ydata)
#      ```
#    Here,
#       - sns stands for seaborn
#       - xdata is an array that contains x values
#       - ydata is an array that contains y values
#
#  - Pandas:
#      ```Python
#     df.plot(kind = 'bar', x= columnx, y = columny)
#     ```
#     Here,
#       - df stands for a DataFrame
#       - columnx, columy are the names of the columns of x and y data, respectively.
#       - NOTE: if your DataFrame only has one column of data, you don't have to specify the columns. Pandas will automatically use the index as x values and the data as y values.

# %%
df_orders['MONTH'] = pd.to_datetime(df_orders['DATETIME']).dt.month

# %%
df_sum_month = df_orders.groupby('MONTH')['DRINKS'].sum()
plt.bar(df_sum_month.index,df_sum_month)

# %%
sns.barplot(data=df_sum_month, x=df_sum_month.index,y=df_sum_month)

# %%
df_sum_month.plot(kind='bar')

# %% [markdown]
# (f) Compute the total cookies for each month. Do the scatter plot of this quantity vs the total drinks each month.
#
#
# #### Scatter plot
#  - Matplotlib:
#     ```Python
#      plt.scatter(xdata,ydata)
#     ```
#     Here,
#       - plt stands for matplotlib.pylot
#       - xdata: an array that contains x values
#       - ydata: an array that contains y values
#  - Seaborn:
#      ```Python
#      sns.scatterplot(x=xdata,y=ydata)
#      ```
#    Here,
#       - sns stands for seaborn
#       - xdata is an array that contains x values
#       - ydata is an array that contains y values
#
#  - Pandas:
#      ```Python
#     df.plot(kind = 'scatter', x= columnx, y = columny)
#     ```
#     Here,
#       - df stands for a DataFrame
#       - columnx, columy are the names of the columns of x and y data, respectively.

# %%
df_cookies_sum = df_orders.groupby('MONTH')['COOKIES'].sum()
plt.scatter(df_cookies_sum,df_sum_month)
plt.xlabel('Cookies')
plt.ylabel('Drinks')
plt.show()

# %%
sns.scatterplot(x=df_cookies_sum,y = df_sum_month)
plt.xlabel('Cookies')
plt.ylabel('Drinks')
plt.show()

# %%
df_drink_cookie = df_orders.groupby('MONTH')['COOKIES','DRINKS'].sum()
df_drink_cookie.plot(kind='scatter',x='COOKIES', y = 'DRINKS',c='r')

# %% [markdown]
# (d) Do the boxplot to summarize the total drinks sold for each date
#
#
# #### Boxplot
# __(a) Single box:__
#
#  - Matplotlib:
#     ```Python
#      plt.box(data)
#     ```
#     Here,
#       - plt stands for matplotlib.pylot
#       - data: an array that contains values
#  - Seaborn:
#      ```Python
#      sns.boxplot(data)
#      ```
#    Here,
#       - sns stands for seaborn
#       - data is an array that contains values
#
#  - Pandas:
#      ```Python
#     df.plot(kind = 'box', column= column_name)
#     ```
#     Here,
#       - df stands for a DataFrame
#       - column_name is the name of column that has the data

# %%
plt.boxplot(df_sum_drinks)
plt.show()

# %%
sns.boxplot(df_sum_drinks)

# %%
df_sum_drinks.plot(kind='box')

# %% [markdown]
# (e) do violin plot for (d)
#
# #### Violin plot:
# Syntax is similar to boxplot. NOTE: Pandas does NOT have violin plot!!!!

# %%
plt.violinplot(df_sum_drinks)
plt.show()

# %%
sns.violinplot(df_sum_drinks)
plt.show()
# Out:
# C:\Users\plumz\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# (g) (Multiple box/violin plot) Make a new DataFrame that contains all orders which have more than 5 drinks. Use the boxplot/violin plot to describe the number of drinks each month.
#
#
# #### Boxplot
#
# __(b) Multiple boxes:__
#
#  - Matplotlib:
#     ```Python
#      plt.box([data])
#     ```
#     Here,
#       - plt stands for matplotlib.pylot
#       - [data] is a list of data array
#
#  - Seaborn:
#      ```Python
#      sns.boxplot(x=columnx, y =columny, data = df)
#      ```
#    Here,
#     - df is a DataFrame
#     - columnx: name is the column that contains the x-values
#     - columny: name is the column that contains the y-values
#
#  - Pandas:
#      ```Python
#     df.plot(kind = 'box', column= [column_names])
#     ```
#     Here,
#       - df stands for a DataFrame
#       - [column_name] is the list of column names.

# %%
df_orders_with_drink = df_orders[df_orders['DRINKS']>5]

# %%
sns.boxplot(x='MONTH', y ='DRINKS', data = df_orders_with_drink)
plt.show()

# %%
sns.boxplot(y = "MONTH", x = "DRINKS", data = df_orders_with_drink, orient = "h")
plt.show()
